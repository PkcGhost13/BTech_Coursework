# %%
import numpy as np
import pandas as pd
df=pd.read_csv("studentsmarks1.csv")
df
# Out:
#       student_id  quiz_1_score  quiz_2_score  quiz_3_score  final_exam_score
# 0              1            65            42            95                10
# 1              2            77            33            71                87
# 2              3            38            41            82                65
# 3              4            97            50            87                48
# 4              5            79            59            92                48
# ...          ...           ...           ...           ...               ...
# 1010        1011            56            22            66                31
# 1011        1012            70            98            12                93
# 1012        1013            49            97            32                94
# 1013        1014            56            78            60                12
# 1014        1015            91            59            72                53
#
# [1015 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        1015 non-null   int64
#  1   quiz_1_score      1015 non-null   int64
#  2   quiz_2_score      1015 non-null   int64
#  3   quiz_3_score      1015 non-null   int64
#  4   final_exam_score  1015 non-null   int64
# dtypes: int64(5)
# memory usage: 39.8 KB

# %%
df.isna().sum()
# Out:
# student_id          0
# quiz_1_score        0
# quiz_2_score        0
# quiz_3_score        0
# final_exam_score    0
# dtype: int64

# %%
quiz_avg=[]
for i in range(1,df.shape[1]-1):
    print("Avg score of quiz ",i," ",np.average(df.iloc[:,i].values))
    quiz_avg.append(np.average(df.iloc[:,i].values))
# Out:
# Avg score of quiz  1   54.98325123152709
# Avg score of quiz  2   55.278817733990145
# Avg score of quiz  3   53.62463054187192

# %%
avg_score=[]
for i in range(df.shape[0]):
    print("Avg score of student ",i,"\t",np.average(df.iloc[i,1:].values))
    avg_score.append(float(np.average(df.iloc[i,1:].values)))
# Out:
# Avg score of student  0 	 53.0
# Avg score of student  1 	 67.0
# Avg score of student  2 	 56.5
# Avg score of student  3 	 70.5
# Avg score of student  4 	 69.5
# Avg score of student  5 	 74.5
# Avg score of student  6 	 59.25
# Avg score of student  7 	 61.0
# Avg score of student  8 	 53.25
# Avg score of student  9 	 82.75
# Avg score of student  10 	 47.5
# Avg score of student  11 	 70.5
# Avg score of student  12 	 64.5
# Avg score of student  13 	 79.75
# Avg score of student  14 	 48.25
# Avg score of student  15 	 74.0
# Avg score of student  16 	 65.75
# Avg score of student  17 	 63.0
# Avg score of student  18 	 53.75
# Avg score of student  19 	 58.0
# Avg score of student  20 	 37.25
# Avg score of student  21 	 39.75
# Avg score of student  22 	 37.75
# Avg score of student  23 	 68.75
# Avg score of student  24 	 56.75
# Avg score of student  25 	 46.25
# Avg score of student  26 	 58.5
# Avg score of student  27 	 34.0
# Avg score of student  28 	 70.75
# ...

# %%
print("The quiz with the highest average marks is : Quiz -",quiz_avg.index(max(quiz_avg))+1,"with the average score of : ",max(quiz_avg))
# Out:
# The quiz with the highest average marks is : Quiz - 2 with the average score of :  55.278817733990145

# %%
sorted_list = sorted(enumerate(avg_score,1), key=lambda x: x[1], reverse=True)
top_20 = sorted_list[:20]
print(top_20)
# Out:
# [(462, 93.25), (519, 92.25), (788, 91.5), (580, 91.0), (551, 90.0), (838, 89.0), (337, 88.0), (892, 87.75), (737, 87.25), (502, 86.5), (720, 85.0), (98, 84.75), (157, 84.75), (155, 84.25), (447, 84.0), (850, 83.0), (10, 82.75), (896, 82.75), (990, 82.25), (960, 81.75)]

# %%
count=0
for i in avg_score:
    if i>=60:
        count+=1
print("The number of students who passed are :",count)
# Out:
# The number of students who passed are : 369

# %%
lr=pd.read_csv("salary_data.csv")
lr
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
X=np.array(lr.iloc[:,0]).reshape(-1, 1)
y=np.array(lr.iloc[:,1])
model=LinearRegression()
model.fit(X,y)
x=np.array([5]).reshape(-1, 1)
y=model.predict(x)
print("The predicted salary should be : Rs %0.2f"%y[0])
# Out:
# The predicted salary should be : Rs 73042.01

# %%
sent=input("Enter the sentence : ")
lst=sent.split(" ")
sw=pd.Series(lst)
pw=sw.value_counts()
print(pw['was'])
# Out:
# Enter the sentence : Nory was a Catholic because her mother was a Catholic, and Nory’s mother was a Catholic because her father was a Catholic, and her father was a Catholic because his mother was a Catholic, or had been
# 6
